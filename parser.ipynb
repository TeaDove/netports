# %%
# !pip3 install beautifulsoup4 requests pydantic

# %%
import requests 
from bs4 import BeautifulSoup
import bs4
from dataclasses import dataclass, asdict
import json
import re

# %%
resp = requests.get("https://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers", headers={"User-Agent": "curl/8.7.1"})
resp.raise_for_status()

soup = BeautifulSoup(resp.text)
soup.title
# Out:
# <title>List of TCP and UDP port numbers - Wikipedia</title>

# %%
@dataclass
class Port:
    start: int
    end: int
    
    category: str 
    description: str 

    types: dict[str, str]

# %%
def purify(v: str) -> str:
    return re.sub(r'\[.*?\d+\]', '', v).strip()

purify("De-assigned on 2025-02-13, previously compressnet[2]\n")
# Out:
# 'De-assigned on 2025-02-13, previously compressnet'

# %%
def port_number_to_range(v: str) -> tuple[int, int]:
    parts = v.split("–")
    if len(parts) == 1:
        port = int(parts[0])
        return port, port

    return int(parts[0]), int(parts[1])

port_number_to_range("10"), port_number_to_range("50–70")
# Out:
# ((10, 10), (50, 70))

# %%
ports: list[Port] = []

for table in soup.select("table.sortable"):
    tbody = table.select_one("tbody")

    category = purify(table.select_one("caption").text)
    
    prev_colspan = 1
    port_number = (1, 1)
    
    for tr in list(tbody.children)[1:]:
        if isinstance(tr, bs4.element.NavigableString):
            continue
            
        children = []
        for child in tr.children:
            if not isinstance(child, bs4.element.Tag):
                continue

            children.append(child)

        rowspaned = True
        prev_colspan -= 1
        if prev_colspan <= 0:
            rowspaned = False
            port_number = port_number_to_range(purify(children[0].text))
            prev_colspan = int(children[0].attrs.get("rowspan", 1))

        types = {}
        port_types = iter(["tcp", "udp", "sctp", "dccp"])

        skip = 0 if rowspaned else 1
        for child in children[skip:-1]:
            text = purify(child.text)
            colspan = int(child.attrs.get("colspan", 1))

            for _ in range(colspan):
                port_type = next(port_types)
                
                if text != "":
                    types[port_type] = text    

        start, end = port_number
        port = Port(start=start, end=end, description = purify(children[-1].text), category=category, types=types)
        ports.append(port)

print(len(ports))
for port in ports[:500]:
    print(port)
# Out:
# 1522
# Port(start=0, end=0, category='Well-known ports', description='In programming APIs (not in communication between hosts), requests a system-allocated (dynamic) port', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1, end=1, category='Well-known ports', description='TCP Port Service Multiplexer (TCPMUX). Historic. Both TCP and UDP have been assigned to TCPMUX by IANA, but by design only TCP is specified.', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=2, end=2, category='Well-known ports', description='De-assigned on 2025-02-13, previously compressnet', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=3, end=3, category='Well-known ports', description='De-assigned on 2025-02-13, previously compressnet', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=5, end=5, category='Well-known ports', description='Remote Job Entry was historically using socket 5 in its old socket form, while MIB PIM has identified it as TCP/5 and IANA has assigned both TCP and UDP 5 to it.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=7, end=7, category='Well-known ports', description='Echo Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=9, end=9, category='Well-known ports', description='Discard Protocol', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes', 'dccp': 'Assigned'})
# Port(start=9, end=9, category='Well-known ports', description='Wake-on-LAN', types={'tcp': 'No', 'udp': 'Unofficial'})
# Port(start=11, end=11, category='Well-known ports', description='Active Users (systat service)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=13, end=13, category='Well-known ports', description='Daytime Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=15, end=15, category='Well-known ports', description='Previously netstat service', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=17, end=17, category='Well-known ports', description='Quote of the Day (QOTD)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=18, end=18, category='Well-known ports', description='Message Send Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=19, end=19, category='Well-known ports', description='Character Generator Protocol (CHARGEN)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=20, end=20, category='Well-known ports', description='File Transfer Protocol (FTP) data transfer', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=21, end=21, category='Well-known ports', description='File Transfer Protocol (FTP) control (command)', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=22, end=22, category='Well-known ports', description='Secure Shell (SSH), secure logins, file transfers (scp, sftp) and port forwarding', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=23, end=23, category='Well-known ports', description='Telnet protocol—unencrypted text communications', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=24, end=24, category='Well-known ports', description='"any private mail system", often used for LMTP.', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=25, end=25, category='Well-known ports', description='Simple Mail Transfer Protocol (SMTP), used for email routing between mail servers', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=27, end=27, category='Well-known ports', description='nsw-fe (NSW User System FE)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=28, end=28, category='Well-known ports', description="Palo Alto Networks' Panorama High Availability (HA) sync encrypted port.", types={'tcp': 'Unofficial'})
# Port(start=29, end=29, category='Well-known ports', description='msg-icp (MSG ICP)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=31, end=31, category='Well-known ports', description='msg-auth (MSG Authentication)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=33, end=33, category='Well-known ports', description='dsp (Display Support Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=37, end=37, category='Well-known ports', description='Time Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=38, end=38, category='Well-known ports', description='rap (Route Access Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=39, end=39, category='Well-known ports', description='rlp (Resource Location Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=41, end=41, category='Well-known ports', description='graphics (Graphics)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=42, end=42, category='Well-known ports', description='Host Name Server Protocol', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=43, end=43, category='Well-known ports', description='WHOIS protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=44, end=44, category='Well-known ports', description='mpm-flags\t(MPM FLAGS Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=45, end=45, category='Well-known ports', description='mpm (Message Processing Module', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=46, end=46, category='Well-known ports', description='mpm-snd (MPM', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=47, end=47, category='Well-known ports', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=48, end=48, category='Well-known ports', description='auditd (Digital Audit Daemon)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=49, end=49, category='Well-known ports', description='TACACS Login Host protocol. TACACS+, still in draft which is an improved but distinct version of TACACS, only uses TCP 49.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=50, end=50, category='Well-known ports', description='re-mail-ck (Remote Mail Checking Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=51, end=51, category='Well-known ports', description='Historically used for Interface Message Processor logical address management, entry has been removed by IANA on 2013-05-25', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=52, end=52, category='Well-known ports', description='Xerox Network Systems (XNS) Time Protocol. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=53, end=53, category='Well-known ports', description='Domain Name System (DNS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=54, end=54, category='Well-known ports', description='Xerox Network Systems (XNS) Clearinghouse (Name Server). Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=55, end=55, category='Well-known ports', description='isi-gl (ISI Graphics Language)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=56, end=56, category='Well-known ports', description='Xerox Network Systems (XNS) Authentication Protocol. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=58, end=58, category='Well-known ports', description='Xerox Network Systems (XNS) Mail. Despite this port being assigned by IANA, the service is meant to work on SPP (ancestor of IPX/SPX), instead of TCP/IP.', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=61, end=61, category='Well-known ports', description="Historically assigned to the NIFTP-Based Mail protocol, but was never documented in the related IEN. The port number entry was removed from IANA's registry on 2017-05-18.", types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=62, end=62, category='Well-known ports', description='acas (ACA Services)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=63, end=63, category='Well-known ports', description='whoispp (whois++)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=64, end=64, category='Well-known ports', description='covia (Communications Integrator (CI))', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=65, end=65, category='Well-known ports', description='tacacs-ds (TACACS-Database Service)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=66, end=66, category='Well-known ports', description='sql-net (Oracle SQL*NET)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=67, end=67, category='Well-known ports', description='Bootstrap Protocol (BOOTP) server; also used by Dynamic Host Configuration Protocol (DHCP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=68, end=68, category='Well-known ports', description='Bootstrap Protocol (BOOTP) client; also used by Dynamic Host Configuration Protocol (DHCP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=69, end=69, category='Well-known ports', description='Trivial File Transfer Protocol (TFTP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=70, end=70, category='Well-known ports', description='Gopher protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=71, end=74, category='Well-known ports', description='NETRJS protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=76, end=76, category='Well-known ports', description='deos (Distributed External Object Store)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=78, end=78, category='Well-known ports', description='vettcp (vettcp)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=79, end=79, category='Well-known ports', description='Finger protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=80, end=80, category='Well-known ports', description='Hypertext Transfer Protocol (HTTP) uses TCP in versions 1.x and 2. HTTP/3 uses QUIC, a transport protocol on top of UDP.', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=81, end=81, category='Well-known ports', description='TorPark onion routing', types={'tcp': 'Unofficial'})
# Port(start=82, end=82, category='Well-known ports', description='xfer (XFER Utility)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=82, end=82, category='Well-known ports', description='TorPark control', types={'udp': 'Unofficial'})
# Port(start=83, end=83, category='Well-known ports', description='mit-ml-dev (MIT ML Device)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=84, end=84, category='Well-known ports', description='ctf (Common Trace Facility)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=85, end=85, category='Well-known ports', description='mit-ml-dev (MIT ML Device)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=86, end=86, category='Well-known ports', description='mfcobol (Micro Focus Cobol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=88, end=88, category='Well-known ports', description='Kerberos authentication system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=89, end=89, category='Well-known ports', description='su-mit-tg\t(SU/MIT Telnet Gateway)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=90, end=90, category='Well-known ports', description='dnsix\t(DNSIX Security Attribute Token Map)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=90, end=90, category='Well-known ports', description='PointCast (dotcom)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=91, end=91, category='Well-known ports', description='mit-dov (MIT Dover Spooler)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=92, end=92, category='Well-known ports', description='npp (Network Printing Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=93, end=93, category='Well-known ports', description='dcp (Device Control Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=94, end=94, category='Well-known ports', description='objcall (Tivoli Object Dispatcher)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=95, end=95, category='Well-known ports', description='SUPDUP, terminal-independent remote login', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=96, end=96, category='Well-known ports', description='dixie (DIXIE Protocol Specification)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=97, end=97, category='Well-known ports', description='swift-rvf (Swift Remote Virtual File Protocol)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=98, end=98, category='Well-known ports', description='tacnews (TAC News)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=99, end=99, category='Well-known ports', description='metagram (Metagram Relay)', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=101, end=101, category='Well-known ports', description='NIC host name', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=102, end=102, category='Well-known ports', description='ISO Transport Service Access Point (TSAP) Class 0 protocol;', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=104, end=104, category='Well-known ports', description='Digital Imaging and Communications in Medicine (DICOM; also port 11112)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=105, end=105, category='Well-known ports', description='CCSO Nameserver', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=106, end=106, category='Well-known ports', description='macOS Server, (macOS) password server', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=107, end=107, category='Well-known ports', description='Remote User Telnet Service (RTelnet)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=108, end=108, category='Well-known ports', description='IBM Systems Network Architecture (SNA) gateway access server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=109, end=109, category='Well-known ports', description='Post Office Protocol, version 2 (POP2)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=110, end=110, category='Well-known ports', description='Post Office Protocol, version 3 (POP3)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=111, end=111, category='Well-known ports', description='Open Network Computing Remote Procedure Call (ONC RPC, sometimes referred to as Sun RPC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=112, end=112, category='Well-known ports', description='McIDAS Data Transmission Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=113, end=113, category='Well-known ports', description='Ident, authentication service/identification protocol, used by IRC servers to identify users', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=113, end=113, category='Well-known ports', description="Authentication Service (auth), the predecessor to identification protocol. Used to determine a user's identity of a particular TCP connection.", types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=115, end=115, category='Well-known ports', description='Simple File Transfer Protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=117, end=117, category='Well-known ports', description='UUCP Mapping Project (path service)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=118, end=118, category='Well-known ports', description='Structured Query Language (SQL) Services[jargon]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=119, end=119, category='Well-known ports', description='Network News Transfer Protocol (NNTP), retrieval of newsgroup messages', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=123, end=123, category='Well-known ports', description='Network Time Protocol (NTP), used for time synchronization', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=126, end=126, category='Well-known ports', description="Formerly Unisys Unitary Login, renamed by Unisys to NXEdit. Used by Unisys Programmer's Workbench for Clearpath MCP, an IDE for Unisys MCP software development", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=135, end=135, category='Well-known ports', description='DCE endpoint resolution', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=135, end=135, category='Well-known ports', description='Microsoft EPMAP (End Point Mapper), also known as DCE/RPC Locator service, used to remotely manage services including DHCP server, DNS server and WINS. Also used by DCOM', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=137, end=137, category='Well-known ports', description='NetBIOS Name Service, used for name registration and resolution', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=138, end=138, category='Well-known ports', description='NetBIOS Datagram Service', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=139, end=139, category='Well-known ports', description='NetBIOS Session Service', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=143, end=143, category='Well-known ports', description='Internet Message Access Protocol (IMAP), management of electronic mail messages on a server', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=151, end=151, category='Well-known ports', description='HEMS', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=152, end=152, category='Well-known ports', description='Background File Transfer Program (BFTP)[importance?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=153, end=153, category='Well-known ports', description='Simple Gateway Monitoring Protocol (SGMP), a protocol for remote inspection and alteration of gateway management information', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=156, end=156, category='Well-known ports', description='Structured Query Language (SQL) Service[jargon]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=158, end=158, category='Well-known ports', description='Distributed Mail System Protocol (DMSP, sometimes referred to as Pcmail)[importance?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=161, end=161, category='Well-known ports', description='Simple Network Management Protocol (SNMP)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=162, end=162, category='Well-known ports', description='Simple Network Management Protocol Trap (SNMPTRAP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=165, end=165, category='Well-known ports', description='Xerox', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=169, end=169, category='Well-known ports', description='SEND', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=170, end=170, category='Well-known ports', description='Network PostScript print server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=175, end=175, category='Well-known ports', description='VMNET service using NJE', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=177, end=177, category='Well-known ports', description='X Display Manager Control Protocol (XDMCP), used for remote logins to an X Display Manager server[self-published source]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=179, end=179, category='Well-known ports', description='Border Gateway Protocol (BGP), used to exchange routing and reachability information among autonomous systems (AS) on the Internet', types={'tcp': 'Yes', 'udp': 'Assigned', 'sctp': 'Yes'})
# Port(start=180, end=180, category='Well-known ports', description='ris', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=194, end=194, category='Well-known ports', description='Internet Relay Chat (IRC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=199, end=199, category='Well-known ports', description='SNMP Unix Multiplexer (SMUX)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=201, end=201, category='Well-known ports', description='AppleTalk Routing Maintenance', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=209, end=209, category='Well-known ports', description='Quick Mail Transfer Protocol[self-published source]', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=210, end=210, category='Well-known ports', description='ANSI Z39.50', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=213, end=213, category='Well-known ports', description='Internetwork Packet Exchange (IPX)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=218, end=218, category='Well-known ports', description='Message posting protocol (MPP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=220, end=220, category='Well-known ports', description='Internet Message Access Protocol (IMAP), version 3', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=225, end=241, category='Well-known ports', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=249, end=255, category='Well-known ports', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=259, end=259, category='Well-known ports', description='Efficient Short Remote Operations (ESRO)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=262, end=262, category='Well-known ports', description='Arcisdms', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=264, end=264, category='Well-known ports', description='Border Gateway Multicast Protocol (BGMP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=280, end=280, category='Well-known ports', description='http-mgmt', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=300, end=300, category='Well-known ports', description='ThinLinc Web Access, Spartan protocol', types={'tcp': 'Unofficial'})
# Port(start=308, end=308, category='Well-known ports', description='Novastor Online Backup', types={'tcp': 'Yes'})
# Port(start=311, end=311, category='Well-known ports', description='macOS Server Admin (officially AppleShare IP Web administration)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=312, end=312, category='Well-known ports', description='macOS Xsan administration', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=318, end=318, category='Well-known ports', description='PKIX Time Stamp Protocol (TSP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=319, end=319, category='Well-known ports', description='Precision Time Protocol (PTP) event messages', types={'udp': 'Yes'})
# Port(start=320, end=320, category='Well-known ports', description='Precision Time Protocol (PTP) general messages', types={'udp': 'Yes'})
# Port(start=323, end=323, category='Well-known ports', description='Resource Public Key Infrastructure', types={'tcp': 'Yes'})
# Port(start=350, end=350, category='Well-known ports', description='Mapping of Airline Traffic over Internet Protocol (MATIP) type A', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=351, end=351, category='Well-known ports', description='MATIP type B', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=356, end=356, category='Well-known ports', description='cloanto-net-1 (used by Cloanto Amiga Explorer and VMs)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=366, end=366, category='Well-known ports', description='On-Demand Mail Relay (ODMR)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=369, end=369, category='Well-known ports', description='Rpc2portmap', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=370, end=370, category='Well-known ports', description='codaauth2, Coda authentication server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=370, end=370, category='Well-known ports', description="securecast1, outgoing packets to NAI's SecureCast serversAs of 2000[update]", types={'udp': 'Yes'})
# Port(start=371, end=371, category='Well-known ports', description='ClearCase albd', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=376, end=376, category='Well-known ports', description='Amiga Envoy Network Inquiry Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=383, end=383, category='Well-known ports', description='HP data alarm manager', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=384, end=384, category='Well-known ports', description='A Remote Network Server System', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=387, end=387, category='Well-known ports', description='AURP (AppleTalk Update-based Routing Protocol)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=388, end=388, category='Well-known ports', description='Unidata LDM near real-time data distribution protocol[self-published source]', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=389, end=389, category='Well-known ports', description='Lightweight Directory Access Protocol (LDAP)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=399, end=399, category='Well-known ports', description='Digital Equipment Corporation DECnet+ (Phase V) over TCP/IP (RFC1859)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=401, end=401, category='Well-known ports', description='Uninterruptible power supply (UPS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=427, end=427, category='Well-known ports', description='Service Location Protocol (SLP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=433, end=433, category='Well-known ports', description='NNTP, part of Network News Transfer Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=434, end=434, category='Well-known ports', description='Mobile IP Agent (RFC 5944)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=443, end=443, category='Well-known ports', description='Hypertext Transfer Protocol Secure (HTTPS) uses TCP in versions 1.x and 2. HTTP/3 uses QUIC, a transport protocol on top of UDP.', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=444, end=444, category='Well-known ports', description='Simple Network Paging Protocol (SNPP), RFC 1568', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=445, end=445, category='Well-known ports', description='Microsoft-DS (Directory Services) Active Directory, Windows shares', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=445, end=445, category='Well-known ports', description='Microsoft-DS (Directory Services) SMB file sharing', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=464, end=464, category='Well-known ports', description='Kpasswd: Kerberos Change/Set password', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=465, end=465, category='Well-known ports', description='Message Submission over TLS protocol', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=465, end=465, category='Well-known ports', description='URL Rendezvous Directory for Cisco SSM', types={'tcp': 'Yes', 'udp': 'No'})
# Port(start=475, end=475, category='Well-known ports', description='tcpnethaspsrv, Aladdin Knowledge Systems Hasp services', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=476, end=490, category='Well-known ports', description='Centro Software ERP ports', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=491, end=491, category='Well-known ports', description='GO-Global remote access and application publishing software', types={'tcp': 'Unofficial'})
# Port(start=497, end=497, category='Well-known ports', description='Retrospect', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=500, end=500, category='Well-known ports', description='Internet Security Association and Key Management Protocol (ISAKMP) / Internet Key Exchange (IKE)', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=502, end=502, category='Well-known ports', description='Modbus Protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=504, end=504, category='Well-known ports', description='Citadel, multiservice protocol for dedicated clients for the Citadel groupware system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=510, end=510, category='Well-known ports', description='FirstClass Protocol (FCP), used by FirstClass client/server groupware system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=512, end=512, category='Well-known ports', description='Rexec, Remote Process Execution', types={'tcp': 'Yes'})
# Port(start=512, end=512, category='Well-known ports', description='comsat, together with biff', types={'udp': 'Yes'})
# Port(start=513, end=513, category='Well-known ports', description='rlogin', types={'tcp': 'Yes'})
# Port(start=513, end=513, category='Well-known ports', description='Who', types={'udp': 'Yes'})
# Port(start=514, end=514, category='Well-known ports', description='Remote Shell, used to execute non-interactive commands on a remote system (Remote Shell, rsh, remsh)', types={'tcp': 'Unofficial'})
# Port(start=514, end=514, category='Well-known ports', description='Syslog, used for system logging', types={'tcp': 'No', 'udp': 'Yes'})
# Port(start=515, end=515, category='Well-known ports', description='Line Printer Daemon (LPD), print service', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=517, end=517, category='Well-known ports', description='Talk', types={'udp': 'Yes'})
# Port(start=518, end=518, category='Well-known ports', description='NTalk', types={'udp': 'Yes'})
# Port(start=520, end=520, category='Well-known ports', description='efs, extended file name server', types={'tcp': 'Yes'})
# Port(start=520, end=520, category='Well-known ports', description='Routing Information Protocol (RIP)', types={'udp': 'Yes'})
# Port(start=521, end=521, category='Well-known ports', description='Routing Information Protocol Next Generation (RIPng)', types={'udp': 'Yes'})
# Port(start=524, end=524, category='Well-known ports', description='NetWare Core Protocol (NCP) is used for a variety things such as access to primary NetWare server resources, Time Synchronization, etc.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=525, end=525, category='Well-known ports', description='Timed, Timeserver', types={'udp': 'Yes'})
# Port(start=530, end=530, category='Well-known ports', description='Remote procedure call (RPC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=532, end=532, category='Well-known ports', description='netnews', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=533, end=533, category='Well-known ports', description='netwall, for emergency broadcasts', types={'udp': 'Yes'})
# Port(start=540, end=540, category='Well-known ports', description='Unix-to-Unix Copy Protocol (UUCP)', types={'tcp': 'Yes'})
# Port(start=542, end=542, category='Well-known ports', description='commerce (Commerce Applications)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=543, end=543, category='Well-known ports', description='klogin, Kerberos login', types={'tcp': 'Yes'})
# Port(start=544, end=544, category='Well-known ports', description='kshell, Kerberos Remote shell', types={'tcp': 'Yes'})
# Port(start=546, end=546, category='Well-known ports', description='DHCPv6 client', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=547, end=547, category='Well-known ports', description='DHCPv6 server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=548, end=548, category='Well-known ports', description='Apple Filing Protocol (AFP) over TCP', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=550, end=550, category='Well-known ports', description='new-rwho, new-who', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=554, end=554, category='Well-known ports', description='Real Time Streaming Protocol (RTSP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=556, end=556, category='Well-known ports', description='Remotefs, RFS, rfs_server', types={'tcp': 'Yes'})
# Port(start=560, end=560, category='Well-known ports', description='rmonitor, Remote Monitor', types={'udp': 'Yes'})
# Port(start=561, end=561, category='Well-known ports', description='monitor', types={'udp': 'Yes'})
# Port(start=563, end=563, category='Well-known ports', description='NNTP over TLS/SSL (NNTPS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=564, end=564, category='Well-known ports', description='9P (Plan 9)', types={'tcp': 'Unofficial'})
# Port(start=585, end=585, category='Well-known ports', description='Previously assigned for use of Internet Message Access Protocol over TLS/SSL (IMAPS), now deregistered in favour of port 993.', types={'tcp': 'No', 'udp': 'No'})
# Port(start=587, end=587, category='Well-known ports', description='Email Message Submission (No longer preferred; see port 465.)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=591, end=591, category='Well-known ports', description='FileMaker 6.0 (and later) Web Sharing (HTTP Alternate, also see port 80)', types={'tcp': 'Yes'})
# Port(start=593, end=593, category='Well-known ports', description='HTTP RPC Ep Map, Remote procedure call over Hypertext Transfer Protocol, often used by Distributed Component Object Model services and Microsoft Exchange Server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=601, end=601, category='Well-known ports', description='Reliable Syslog Service — used for system logging', types={'tcp': 'Yes'})
# Port(start=604, end=604, category='Well-known ports', description='TUNNEL profile, a protocol for BEEP peers to form an application layer tunnel', types={'tcp': 'Yes'})
# Port(start=623, end=623, category='Well-known ports', description='ASF Remote Management and Control Protocol (ASF-RMCP) & IPMI Remote Management Protocol', types={'udp': 'Yes'})
# Port(start=625, end=625, category='Well-known ports', description='Open Directory Proxy (ODProxy)', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=631, end=631, category='Well-known ports', description='Internet Printing Protocol (IPP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=631, end=631, category='Well-known ports', description='Common Unix Printing System (CUPS) administration console (extension to IPP)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=635, end=635, category='Well-known ports', description='RLZ DBase', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=636, end=636, category='Well-known ports', description='Lightweight Directory Access Protocol over TLS/SSL (LDAPS)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=639, end=639, category='Well-known ports', description='Multicast Source Discovery Protocol, MSDP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=641, end=641, category='Well-known ports', description='SupportSoft Nexus Remote Command (control/listening), a proxy gateway connecting remote control traffic', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=643, end=643, category='Well-known ports', description='SANity', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=646, end=646, category='Well-known ports', description='Label Distribution Protocol (LDP), a routing protocol used in MPLS networks', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=647, end=647, category='Well-known ports', description='DHCP Failover protocol', types={'tcp': 'Yes'})
# Port(start=648, end=648, category='Well-known ports', description='Registry Registrar Protocol (RRP)', types={'tcp': 'Yes'})
# Port(start=651, end=651, category='Well-known ports', description='IEEE-MMS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=653, end=653, category='Well-known ports', description='SupportSoft Nexus Remote Command (data), a proxy gateway connecting remote control traffic', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=654, end=654, category='Well-known ports', description='Media Management System (MMS) Media Management Protocol (MMP)', types={'tcp': 'Yes'})
# Port(start=655, end=655, category='Well-known ports', description='Tinc VPN daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=657, end=657, category='Well-known ports', description='IBM RMC (Remote monitoring and Control) protocol, used by System p5 AIX Integrated Virtualization Manager (IVM) and Hardware Management Console to connect managed logical partitions (LPAR) to enable dynamic partition reconfiguration', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=660, end=660, category='Well-known ports', description='macOS Server administration, version 10.4 and earlier', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=662, end=662, category='Well-known ports', description='NFS v3 Statd port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=666, end=666, category='Well-known ports', description='Doom, the first online first-person shooter', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=666, end=666, category='Well-known ports', description="airserv-ng, aircrack-ng's server for remote-controlling wireless devices", types={'tcp': 'Unofficial'})
# Port(start=674, end=674, category='Well-known ports', description='Application Configuration Access Protocol (ACAP)', types={'tcp': 'Yes'})
# Port(start=684, end=684, category='Well-known ports', description='CORBA IIOP SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=688, end=688, category='Well-known ports', description='REALM-RUSD (ApplianceWare Server Appliance Management Protocol)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=690, end=690, category='Well-known ports', description='Velneo Application Transfer Protocol (VATP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=691, end=691, category='Well-known ports', description='MS Exchange Routing', types={'tcp': 'Yes'})
# Port(start=694, end=694, category='Well-known ports', description='Linux-HA high-availability heartbeat', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=695, end=695, category='Well-known ports', description='IEEE Media Management System over SSL (IEEE-MMS-SSL)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=698, end=698, category='Well-known ports', description='Optimized Link State Routing (OLSR)', types={'udp': 'Yes'})
# Port(start=700, end=700, category='Well-known ports', description='Extensible Provisioning Protocol (EPP), a protocol for communication between domain name registries and registrars (RFC 5734)', types={'tcp': 'Yes'})
# Port(start=701, end=701, category='Well-known ports', description='Link Management Protocol (LMP), a protocol that runs between a pair of nodes and is used to manage traffic engineering (TE) links', types={'tcp': 'Yes'})
# Port(start=702, end=702, category='Well-known ports', description='IRIS (Internet Registry Information Service) over BEEP (Blocks Extensible Exchange Protocol) (RFC 3983)', types={'tcp': 'Yes'})
# Port(start=706, end=706, category='Well-known ports', description='Secure Internet Live Conferencing (SILC)', types={'tcp': 'Yes'})
# Port(start=711, end=711, category='Well-known ports', description='Cisco Tag Distribution Protocol—being replaced by the MPLS Label Distribution Protocol', types={'tcp': 'Yes'})
# Port(start=712, end=712, category='Well-known ports', description='Topology Broadcast based on Reverse-Path Forwarding routing protocol (TBRPF; RFC 3684)', types={'tcp': 'Yes'})
# Port(start=749, end=749, category='Well-known ports', description='Kerberos administration', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=750, end=750, category='Well-known ports', description='kerberos-iv, Kerberos version IV', types={'udp': 'Yes'})
# Port(start=751, end=751, category='Well-known ports', description='kerberos_master, Kerberos authentication', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=752, end=752, category='Well-known ports', description='passwd_server, Kerberos password (kpasswd) server', types={'udp': 'Unofficial'})
# Port(start=753, end=753, category='Well-known ports', description='Reverse Routing Header (RRH)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=753, end=753, category='Well-known ports', description='userreg_server, Kerberos userreg server', types={'udp': 'Unofficial'})
# Port(start=754, end=754, category='Well-known ports', description='tell send', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=754, end=754, category='Well-known ports', description='krb5_prop, Kerberos v5 slave propagation', types={'tcp': 'Unofficial'})
# Port(start=760, end=760, category='Well-known ports', description='krbupdate [kreg], Kerberos registration', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=777, end=777, category='Well-known ports', description='machine socket eXtension [msx] protocol', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=782, end=782, category='Well-known ports', description='Conserver serial-console management server', types={'tcp': 'Unofficial'})
# Port(start=783, end=783, category='Well-known ports', description='SpamAssassin spamd daemon', types={'tcp': 'Unofficial'})
# Port(start=800, end=800, category='Well-known ports', description='mdbs-daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=802, end=802, category='Well-known ports', description='MODBUS/TCP Security', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=808, end=808, category='Well-known ports', description='Microsoft Net.TCP Port Sharing Service', types={'tcp': 'Unofficial'})
# Port(start=829, end=829, category='Well-known ports', description='Certificate Management Protocol', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=830, end=830, category='Well-known ports', description='NETCONF over SSH', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=831, end=831, category='Well-known ports', description='NETCONF over BEEP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=832, end=832, category='Well-known ports', description='NETCONF for SOAP over HTTPS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=833, end=833, category='Well-known ports', description='NETCONF for SOAP over BEEP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=843, end=843, category='Well-known ports', description='Adobe Flash', types={'tcp': 'Unofficial'})
# Port(start=847, end=847, category='Well-known ports', description='DHCP Failover protocol', types={'tcp': 'Yes'})
# Port(start=848, end=848, category='Well-known ports', description='Group Domain Of Interpretation (GDOI) protocol', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=853, end=853, category='Well-known ports', description='DNS over TLS (RFC 7858)', types={'tcp': 'Yes'})
# Port(start=853, end=853, category='Well-known ports', description='DNS over QUIC or DNS over DTLS', types={'udp': 'Yes'})
# Port(start=860, end=860, category='Well-known ports', description='iSCSI (RFC 3720)', types={'tcp': 'Yes'})
# Port(start=861, end=861, category='Well-known ports', description='OWAMP control (RFC 4656)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=862, end=862, category='Well-known ports', description='TWAMP control (RFC 5357)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=873, end=873, category='Well-known ports', description='rsync file synchronization protocol', types={'tcp': 'Yes'})
# Port(start=888, end=888, category='Well-known ports', description='cddbp, CD DataBase (CDDB) protocol (CDDBP)', types={'tcp': 'Unofficial'})
# Port(start=888, end=888, category='Well-known ports', description='IBM Endpoint Manager Remote Control', types={'tcp': 'Unofficial'})
# Port(start=892, end=892, category='Well-known ports', description='NFS v3 Mountd port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=897, end=897, category='Well-known ports', description='Brocade SMI-S RPC', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=898, end=898, category='Well-known ports', description='Brocade SMI-S RPC SSL', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=902, end=902, category='Well-known ports', description='VMware ESXi', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=903, end=903, category='Well-known ports', description='VMware ESXi', types={'tcp': 'Unofficial'})
# Port(start=953, end=953, category='Well-known ports', description='BIND remote name daemon control (RNDC)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=981, end=981, category='Well-known ports', description='Remote HTTPS management for firewall devices running embedded Check Point VPN-1 software', types={'tcp': 'Unofficial'})
# Port(start=987, end=987, category='Well-known ports', description='Sony PlayStation Wake On Lan', types={'udp': 'Unofficial'})
# Port(start=987, end=987, category='Well-known ports', description='Microsoft Remote Web Workplace, a feature of Windows Small Business Server', types={'tcp': 'Unofficial'})
# Port(start=988, end=988, category='Well-known ports', description='Lustre (file system) Protocol (data).', types={'tcp': 'Unofficial'})
# Port(start=989, end=989, category='Well-known ports', description='FTPS Protocol (data), FTP over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=990, end=990, category='Well-known ports', description='FTPS Protocol (control), FTP over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=991, end=991, category='Well-known ports', description='Netnews Administration System (NAS)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=992, end=992, category='Well-known ports', description='Telnet protocol over TLS/SSL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=993, end=993, category='Well-known ports', description='Internet Message Access Protocol over TLS/SSL (IMAPS)', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=994, end=994, category='Well-known ports', description='Previously assigned to Internet Relay Chat over TLS/SSL (IRCS), but was not used in common practice.', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=995, end=995, category='Well-known ports', description='Post Office Protocol 3 over TLS/SSL (POP3S)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1010, end=1010, category='Well-known ports', description='ThinLinc web-based administration interface', types={'tcp': 'Unofficial'})
# Port(start=1011, end=1020, category='Well-known ports', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1023, end=1023, category='Well-known ports', description='', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1023, end=1023, category='Well-known ports', description='z/OS Network File System (NFS) (potentially ports 991–1023)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1024, end=1024, category='Registered ports', description='Reserved', types={'tcp': 'Reserved', 'udp': 'Reserved'})
# Port(start=1025, end=1025, category='Registered ports', description='network blackjack', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=1027, end=1027, category='Registered ports', description='Reserved', types={'tcp': 'Reserved'})
# Port(start=1027, end=1027, category='Registered ports', description='Native IPv6 behind IPv4-to-IPv4 NAT Customer Premises Equipment (6a44)', types={'udp': 'Yes'})
# Port(start=1029, end=1029, category='Registered ports', description='Microsoft DCOM services', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1058, end=1058, category='Registered ports', description='nim, IBM AIX Network Installation Manager (NIM)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1059, end=1059, category='Registered ports', description='nimreg, IBM AIX Network Installation Manager (NIM)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1080, end=1080, category='Registered ports', description='SOCKS proxy', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1085, end=1085, category='Registered ports', description='WebObjects', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1098, end=1098, category='Registered ports', description='rmiactivation, Java remote method invocation (RMI) activation', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1099, end=1099, category='Registered ports', description='rmiregistry, Java remote method invocation (RMI) registry', types={'tcp': 'Yes', 'udp': 'Assigned'})
# Port(start=1100, end=1100, category='Registered ports', description='SaltoSystems - Handshake for IP-Components', types={'udp': 'Unofficial'})
# Port(start=1112, end=1112, category='Registered ports', description='ESET virus updates', types={'tcp': 'Unofficial'})
# Port(start=1113, end=1113, category='Registered ports', description='Licklider Transmission Protocol (LTP) delay tolerant networking protocol', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1119, end=1119, category='Registered ports', description="Battle.net chat/game protocol, used by Blizzard's games", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1144, end=1144, category='Registered ports', description='fuscript (Fusion Script) used by Blackmagic Design Fusion and DaVinci Resolve', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1167, end=1167, category='Registered ports', description='Cisco IP SLA (Service Assurance Agent)', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=1194, end=1194, category='Registered ports', description='OpenVPN', types={'tcp': 'Yes', 'udp': 'Yes'})
# ...
# Port(start=1755, end=1755, category='Registered ports', description='Microsoft Media Services (MMS, ms-streaming)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1761, end=1761, category='Registered ports', description='Novell ZENworks', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1776, end=1776, category='Registered ports', description='Emergency management information system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1801, end=1801, category='Registered ports', description='Microsoft Message Queuing', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1812, end=1812, category='Registered ports', description='RADIUS authentication protocol, radius', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1813, end=1813, category='Registered ports', description='RADIUS accounting protocol, radius-acct', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1863, end=1863, category='Registered ports', description='Microsoft Notification Protocol (MSNP), used by the Microsoft Messenger service and a number of instant messaging Messenger clients', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1880, end=1880, category='Registered ports', description='Node-RED', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1883, end=1883, category='Registered ports', description='MQTT (formerly MQ Telemetry Transport)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1900, end=1900, category='Registered ports', description='Simple Service Discovery Protocol (SSDP), discovery of UPnP devices', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1935, end=1935, category='Registered ports', description="Macromedia Flash Communications Server MX, the precursor to Adobe Flash Media Server before Macromedia's acquisition by Adobe on December 3, 2005", types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1935, end=1935, category='Registered ports', description='Real Time Messaging Protocol (RTMP)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=1965, end=1965, category='Registered ports', description='Gemini, a lightweight, collaboratively designed protocol, striving to fill the gap between Gopher and HTTP', types={'tcp': 'Unofficial', 'udp': 'No'})
# Port(start=1967, end=1967, category='Registered ports', description='Cisco IOS IP Service Level Agreements (IP SLAs) Control Protocol[citation needed]', types={'udp': 'Unofficial'})
# Port(start=1972, end=1972, category='Registered ports', description='InterSystems Caché, and InterSystems IRIS versions 2020.3 and later', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1984, end=1984, category='Registered ports', description='Big Brother', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=1984, end=1984, category='Registered ports', description='Arweave mining node', types={'tcp': 'Unofficial'})
# Port(start=1985, end=1985, category='Registered ports', description='Cisco Hot Standby Router Protocol (HSRP)[self-published source]', types={'tcp': 'Assigned', 'udp': 'Yes'})
# Port(start=1998, end=1998, category='Registered ports', description='Cisco X.25 over TCP (XOT) service', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2000, end=2000, category='Registered ports', description='Cisco Skinny Client Control Protocol (SCCP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2001, end=2009, category='Registered ports', description='hexss http server (python package)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2010, end=2010, category='Registered ports', description='Artemis: Spaceship Bridge Simulator', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2019, end=2019, category='Registered ports', description='Caddy admin API endpoint', types={'tcp': 'Unofficial'})
# Port(start=2033, end=2033, category='Registered ports', description='Civilization IV multiplayer', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2049, end=2049, category='Registered ports', description='Network File System (NFS)', types={'tcp': 'Yes', 'udp': 'Yes', 'sctp': 'Yes'})
# Port(start=2056, end=2056, category='Registered ports', description='Civilization IV multiplayer', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2080, end=2080, category='Registered ports', description='Autodesk NLM (FLEXlm)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2082, end=2082, category='Registered ports', description='cPanel default', types={'tcp': 'Unofficial'})
# Port(start=2083, end=2083, category='Registered ports', description='Secure RADIUS Service (radsec)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2083, end=2083, category='Registered ports', description='cPanel default TLS', types={'tcp': 'Unofficial'})
# Port(start=2086, end=2086, category='Registered ports', description='GNUnet', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2086, end=2086, category='Registered ports', description='WebHost Manager default', types={'tcp': 'Unofficial'})
# Port(start=2087, end=2087, category='Registered ports', description='WebHost Manager default TLS', types={'tcp': 'Unofficial'})
# Port(start=2095, end=2095, category='Registered ports', description='cPanel default web mail', types={'tcp': 'Yes'})
# Port(start=2096, end=2096, category='Registered ports', description='cPanel default TLS web mail', types={'tcp': 'Unofficial'})
# Port(start=2100, end=2100, category='Registered ports', description='Warzone 2100 multiplayer[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2101, end=2101, category='Registered ports', description='Networked Transport of RTCM via Internet Protocol (NTRIP)[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2102, end=2102, category='Registered ports', description='Zephyr Notification Service server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2103, end=2103, category='Registered ports', description='Zephyr Notification Service serv-hm connection', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2104, end=2104, category='Registered ports', description='Zephyr Notification Service hostmanager', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2123, end=2123, category='Registered ports', description='GTP control messages (GTP-C)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2137, end=2137, category='Registered ports', description='', types={'tcp': 'Unofficial', 'udp': 'Unofficial', 'sctp': 'Unofficial', 'dccp': 'Unofficial'})
# Port(start=2142, end=2142, category='Registered ports', description='TDMoIP (TDM over IP)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2152, end=2152, category='Registered ports', description='GTP user data messages (GTP-U)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2159, end=2159, category='Registered ports', description='GDB remote debug port', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2181, end=2181, category='Registered ports', description='EForward-document transport system', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2181, end=2181, category='Registered ports', description='Apache ZooKeeper default client port[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2195, end=2195, category='Registered ports', description='Apple Push Notification Service, binary, gateway.  Deprecated March 2021.', types={'tcp': 'Unofficial'})
# Port(start=2196, end=2196, category='Registered ports', description='Apple Push Notification Service, binary, feedback.  Deprecated March 2021.', types={'tcp': 'Unofficial'})
# Port(start=2197, end=2197, category='Registered ports', description='Apple Push Notification Service, HTTP/2, JSON-based API.', types={'tcp': 'Unofficial'})
# Port(start=2210, end=2210, category='Registered ports', description='NOAAPORT Broadcast Network', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2211, end=2211, category='Registered ports', description='EMWIN', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2221, end=2221, category='Registered ports', description='ESET anti-virus updates', types={'tcp': 'Unofficial'})
# Port(start=2222, end=2222, category='Registered ports', description='EtherNet/IP implicit messaging for IO data', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2222, end=2222, category='Registered ports', description='DirectAdmin Access', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2222, end=2226, category='Registered ports', description='ESET Remote administrator', types={'tcp': 'Yes'})
# Port(start=2240, end=2240, category='Registered ports', description='General Dynamics Remote Encryptor Configuration Information Protocol (RECIPe)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2261, end=2261, category='Registered ports', description='CoMotion master', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2262, end=2262, category='Registered ports', description='CoMotion backup', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2302, end=2302, category='Registered ports', description='ArmA multiplayer', types={'udp': 'Unofficial'})
# Port(start=2302, end=2302, category='Registered ports', description='Halo: Combat Evolved multiplayer host', types={'udp': 'Unofficial'})
# Port(start=2303, end=2303, category='Registered ports', description='ArmA multiplayer (default port for game +1)', types={'udp': 'Unofficial'})
# Port(start=2303, end=2303, category='Registered ports', description='Halo: Combat Evolved multiplayer listener', types={'udp': 'Unofficial'})
# Port(start=2305, end=2305, category='Registered ports', description='ArmA multiplayer (default port for game +3)', types={'udp': 'Unofficial'})
# Port(start=2351, end=2351, category='Registered ports', description='AIM game LAN network port[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2368, end=2368, category='Registered ports', description='Ghost (blogging platform)', types={'tcp': 'Unofficial'})
# Port(start=2369, end=2369, category='Registered ports', description='Default for BMC Control-M/Server Configuration Agent', types={'tcp': 'Unofficial'})
# Port(start=2370, end=2370, category='Registered ports', description='Default for BMC Control-M/Server, to allow the Control-M/Enterprise Manager to connect to the Control-M/Server', types={'tcp': 'Unofficial'})
# Port(start=2372, end=2372, category='Registered ports', description='Default for K9 Web Protection/parental controls, content filtering agent[citation needed]', types={'tcp': 'Unofficial'})
# Port(start=2375, end=2375, category='Registered ports', description='Docker REST API (plain)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2376, end=2376, category='Registered ports', description='Docker REST API (SSL)', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2377, end=2377, category='Registered ports', description='Docker Swarm cluster management communications[self-published source]', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2379, end=2379, category='Registered ports', description='CoreOS etcd client communication', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2379, end=2379, category='Registered ports', description='KGS Go Server', types={'tcp': 'Unofficial'})
# Port(start=2380, end=2380, category='Registered ports', description='CoreOS etcd server communication', types={'tcp': 'Yes', 'udp': 'Reserved'})
# Port(start=2389, end=2389, category='Registered ports', description='OpenView Session Mgr', types={'tcp': 'Assigned', 'udp': 'Assigned'})
# Port(start=2399, end=2399, category='Registered ports', description='FileMaker Data Access Layer (ODBC/JDBC)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2401, end=2401, category='Registered ports', description='CVS version control system password-based server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2404, end=2404, category='Registered ports', description='IEC 60870-5-104, used to send electric power telecontrol messages between two systems via directly connected data circuits', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2424, end=2424, category='Registered ports', description='OrientDB database listening for binary client connections', types={'tcp': 'Unofficial'})
# Port(start=2426, end=2426, category='Registered ports', description='VMware VeloCloud Multipath Protocol (VCMP) Dynamic Multipath Optimization (DMPO)', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2427, end=2427, category='Registered ports', description='Media Gateway Control Protocol (MGCP) media gateway', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2447, end=2447, category='Registered ports', description='ovwdb—OpenView Network Node Manager (NNM) daemon', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2456, end=2456, category='Registered ports', description='Valheim', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2459, end=2459, category='Registered ports', description='XRPL', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2480, end=2480, category='Registered ports', description='OrientDB database listening for HTTP client connections', types={'tcp': 'Unofficial'})
# Port(start=2483, end=2483, category='Registered ports', description='Oracle database listening for insecure client connections, replaces port 1521[when?]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2484, end=2484, category='Registered ports', description='Oracle database listening for SSL client connections', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2500, end=2500, category='Registered ports', description='NetFS communication', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2501, end=2501, category='Registered ports', description='NetFS probe', types={'udp': 'Unofficial'})
# Port(start=2535, end=2535, category='Registered ports', description='Multicast Address Dynamic Client Allocation Protocol (MADCAP). All standard messages are UDP datagrams.', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2541, end=2541, category='Registered ports', description='LonTalk/IP', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2546, end=2548, category='Registered ports', description='EVault data protection services', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2593, end=2593, category='Registered ports', description='Ultima Online servers[citation needed]', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2598, end=2598, category='Registered ports', description='Citrix Independent Computing Architecture (ICA) with Session Reliability; port 1494 without session reliability', types={'tcp': 'Unofficial'})
# Port(start=2599, end=2599, category='Registered ports', description='Ultima Online servers[citation needed]', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2628, end=2628, category='Registered ports', description='DICT', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2638, end=2638, category='Registered ports', description='SQL Anywhere database server', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2710, end=2710, category='Registered ports', description='XBT Tracker. UDP tracker extension is considered experimental.', types={'tcp': 'Unofficial', 'udp': 'Unofficial'})
# Port(start=2727, end=2727, category='Registered ports', description='Media Gateway Control Protocol (MGCP) media gateway controller (call agent)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2759, end=2759, category='Registered ports', description='SuperTuxKart server', types={'udp': 'Unofficial'})
# Port(start=2761, end=2761, category='Registered ports', description='DICOM over Integrated Secure Communication Layer (ISCL)', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2762, end=2762, category='Registered ports', description='DICOM over TLS', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2775, end=2775, category='Registered ports', description='Short Message Peer-to-Peer (SMPP)[citation needed]', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2809, end=2809, category='Registered ports', description='corbaloc:iiop URL, per the CORBA 3.0.3 specification', types={'tcp': 'Yes', 'udp': 'Yes'})
# Port(start=2811, end=2811, category='Registered ports', description='gsi ftp, per the GridFTP specification', types={'tcp': 'Yes', 'udp': 'Yes'})

# %%
with open("ports.json", "w") as f:
    json.dump([asdict(port) for port in ports], f)
